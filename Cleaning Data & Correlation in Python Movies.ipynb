# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8) # Adjusts the configuration of the plots we will create

# Read in the data
df = pd.read_csv(r'D:\Road to Data Analyst\Data Analyst Porfolio Project #3 (Correlation in Python)\movies.csv')

# %%
# Look at data

df.head()

# %%
# Check for missing data
# Loop through every column to check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))

# %%
# Data types for columns

df.dtypes

# %%
# Change data type of columns
# errors = 'coerce' turns invalid data into NaN
# .fillna(0) replaces them with zero
# .astype('int64) succeeds cleanly

df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype('int64')
df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype('int64')

# %%
df

# %%
# Create a correct Year column
# Regular expression to find the first 4-digit number in each string

df['yearcorrect'] = df['released'].astype(str).str.extract(r'(\d{4})')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Check existing columns, not saved yet
df.columns.tolist()

# %%
# Check for the highest gross in ascending order

df = df.sort_values(by=['gross'], inplace=False, ascending = False)

# %%
# Add scroll feature
pd.set_option('display.max_rows', None)

# %%
# Before dropping duplicates
df['company'].sort_values(ascending=False)

# %%
# Drop any duplicates
# To remove duplicate company names, can use df = df.drop_duplicates(subset=['company'])
# To tidy up the DataFrame, can use df = df.reset_index(drop=True)
df.drop_duplicates()

# %%
df

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')

plt.show()

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  2334       55  237000000  2847246203     2253    162.0           29
# 7445  2241       55  356000000  2797501328     1606    181.0           39
# 3045  1595       55  200000000  2201647264     2253    194.0           17
# 6663   524       55  245000000  2069521700     1540    138.0           35
# 7244  2241       55  321000000  2048359754     1606    149.0           38

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y = 'gross', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"}) # Show Correlation / Trend
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Looking at Correlation
df.corr(method = 'pearson', numeric_only=True) # Different methods for correlation pearson, kendall and spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# High correlation between budget and gross

# %%
# Using matrix to show correlation between features
correlation_matrix = df.corr(method = 'pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Display company column from dataset
df['company'].head()
# Out:
# 0          Warner Bros.
# 1     Columbia Pictures
# 2             Lucasfilm
# 3    Paramount Pictures
# 4        Orion Pictures
# Name: company, dtype: object

# %%
# Numerising columns that are 'object' type
df_numerized = df 
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
# Using matrix to show correlation for every single field

correlation_matrix = df_numerized.corr(method = 'pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Generate correlation matrix for all numeric features
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
# Flatten correlation matrix into single column of correlation pairs
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
# Showing all correlation pairs (disable row limit)
pd.set_option('display.max_rows', None) 
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009211
#              runtime        0.010392
#              yearcorrect    0.010225
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
# ...

# %%
# Sort correlation pairs from weakest to strongest
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
#              gross         -0.234297
# gross        genre         -0.234297
# votes        genre         -0.145307
# genre        votes         -0.145307
# score        country       -0.133348
# country      score         -0.133348
# rating       gross         -0.095450
# gross        rating        -0.095450
# budget       rating        -0.081939
# rating       budget        -0.081939
# genre        year          -0.081261
# year         genre         -0.081261
# country      yearcorrect   -0.079009
# yearcorrect  country       -0.079009
# runtime      country       -0.078412
# country      runtime       -0.078412
# yearcorrect  genre         -0.078210
# genre        yearcorrect   -0.078210
#              company       -0.071067
# company      genre         -0.071067
# year         country       -0.070938
# country      year          -0.070938
# runtime      genre         -0.052711
# ...

# %%
# Check strongest correlations (above 0.5 threshold)
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross        votes          0.632834
# votes        gross          0.632834
# gross        budget         0.750157
# budget       gross          0.750157
# yearcorrect  year           0.996397
# year         yearcorrect    0.996397
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings
# Company has low correlation
